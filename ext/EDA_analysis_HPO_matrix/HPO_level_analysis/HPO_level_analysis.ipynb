# %% [markdown]
# Questions:
# - Diversité des HPO
# - co-occurrence dans les textes
# - Différnece entre 2025 et 2022
# - calculer une distance sur une ontologie pour servir de guide dans la validation du clustering
